# %%
# Import libraries
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, random_split
import torch.optim as optim
from torch.autograd import Variable
import pathlib
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix, ConfusionMatrixDisplay
import numpy as np
from PIL import ImageFile, Image
import onnx, onnxscript


# Device Configuration
if torch.cuda.is_available():
    device = torch.device('cuda')       #Use this for Windows, Google Colab
elif torch.backends.mps.is_available():
    device = torch.device('mps')        #Use this for MacOS
else:
    device = torch.device('cpu')

# %% [markdown]
# [View our dataset on Google Drive here](https://drive.google.com/drive/folders/1F1LxmTDe8oy9KEKCgCGSUMAZuHX4ebRJ?usp=sharing)

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# Split data into train set, test set, validation set and their respective directories

# %%
#Create Dataloaders and Preprocess Data
#Based off of code from https://github.com/gaurav67890/Pytorch_Tutorials/blob/master/cnn-scratch-training.ipynb

transformer=transforms.Compose([
    transforms.Resize((128,128)),       # TODO: decide what to modify this to
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),              # 0-255 to 0-1, numpy to tensors
    transforms.Normalize([0.5,0.5,0.5], # 0-1 to [-1,1] , formula (x-mean)/std
                        [0.5,0.5,0.5])
])


#Path variables to data directory
#data_path='/content/drive/MyDrive/SENG_474_Dataset_10k'       #Path on Google Drive
data_path='SENG_474_Dataset_Filtered'                            #Local Path

# seed to keep random split the same each time
seed = 42
generator = torch.Generator().manual_seed(seed)

full_dataset = torchvision.datasets.ImageFolder(data_path, transform=transformer)

# 3-way split split
train_size = int(0.8 * len(full_dataset))
test_size = int(0.2 * len(full_dataset))

#split the data
train_dataset, test_dataset = random_split(full_dataset, [train_size, test_size], generator=generator)


train_loader = DataLoader(train_dataset,
                          batch_size=64,
                          shuffle=True,
                          num_workers=4
                          )

test_loader = DataLoader(test_dataset,
                         batch_size=64,
                         shuffle=True,   # - falsed out shuffle for now, to keep evaluation deterministic? - kedan
                         num_workers=4
                         )

#print to make sure classes were assigned correct label
print(full_dataset.class_to_idx)

#print number of images
print(f"Total images: {len(full_dataset)}")
print(f"Training images: {len(train_dataset)}")
print(f"Testing images: {len(test_dataset)}")
# Out:
# {'0-Human': 0, '1-AI': 1}
# Total images: 20000
# Training images: 16000
# Testing images: 4000

# %%
#PyTorch Tutorial 14 - Convolutional Neural Network (CNN) by Patrick Loeber on YouTube
# https://www.youtube.com/watch?v=pDdP0TFzsoQ

def showImages(img):
    #Show random images from the training set
    img = img / 2 + 0.5 #unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1,2,0)))
    plt.show()


dataiter = iter(train_loader)
images, labels = next(dataiter)
showImages(torchvision.utils.make_grid(images))
# Out:
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()

        self.conv1 = nn.Conv2d(3, 64, 3, padding=1)       # [64, 64, 64] after pool
        self.bnorm_conv1 = nn.BatchNorm2d(64)

        self.conv2 = nn.Conv2d(64, 128, 3, padding=1)    # [128, 32, 32] after pool
        self.bnorm_conv2 = nn.BatchNorm2d(128)

        self.conv3 = nn.Conv2d(128, 256, 3, padding=1)    # [256, 16, 16] after pool
        self.bnorm_conv3 = nn.BatchNorm2d(256)

        self.pool = nn.MaxPool2d(2, 2)
        self.do1 = nn.Dropout(0.4)

        self.fc1 = nn.Linear(256 * 16 * 16, 120) 
        self.bnorm_fc1 = nn.BatchNorm1d(120)
        self.do2 = nn.Dropout(0.4)

        self.fc2 = nn.Linear(120, 18)
        self.bnorm_fc2 = nn.BatchNorm1d(18)
        self.do3 = nn.Dropout(0.1)

        self.fc3 = nn.Linear(18, 2)

    def forward(self, x):
        x = self.pool(F.relu(self.bnorm_conv1(self.conv1(x))))  # --> [64, 64, 64]
        x = self.pool(F.relu(self.bnorm_conv2(self.conv2(x))))  # --> [128, 32, 32]
        x = self.pool(F.relu(self.bnorm_conv3(self.conv3(x))))  # --> [256, 16, 16]

        x = torch.flatten(x, 1)  # [batch_size, 65536]

        x = self.do1(x)
        x = F.relu(self.bnorm_fc1(self.fc1(x)))
        x = self.do2(x)
        x = F.relu(self.bnorm_fc2(self.fc2(x)))
        x = self.do3(x)
        x = self.fc3(x)

        return x

# %%
# Train the model
ImageFile.LOAD_TRUNCATED_IMAGES=True

model = CNN().to(device)

# Define hyper-parameters
num_epochs = 24
learning_rate = 0.001

criterion = nn.CrossEntropyLoss()
# optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9)
# scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=2, factor=0.1, min_lr=1e-6)     # TODO: SGD or Adam??? comapre training results

optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=0.0001)  # Adam optimizer with weight decay for regularization (lambda=0.00001)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=2, factor=0.1, min_lr=1e-6)

# storing metrics for all epoches
train_losses = []
learning_rates = []

n_total_training_steps = len(train_loader)
training_halfway = n_total_training_steps//2

for epoch in range (num_epochs):
    model.train()
    #storing running total of loss for current epoch
    training_running_loss_first = 0.0
    training_running_loss_second = 0.0

    current_lr = optimizer.param_groups[0]['lr']
    learning_rates.append(current_lr)
    print(f'=== Epoch {epoch+1}: Current LR: {current_lr} ===')

    corrupted = 0

    i = 0
    train_loader_iter = iter(train_loader)
    while True:
        try:
            batch = next(train_loader_iter)
            images, labels = batch
            images = images.to(device)
            labels = labels.to(device)

            # Forward propagation
            outputs = model(images) # predictions
            train_loss = criterion(outputs, labels)

            # Backward propagation and optimization
            optimizer.zero_grad()
            train_loss.backward()
            optimizer.step()        # applied every batch

            i += 1 
        except StopIteration:
            break  # End of DataLoader
        except OSError:
            corrupted += 1
            i += 1 
            continue

        if i < training_halfway:
            training_running_loss_first += train_loss.item()
        else:
            training_running_loss_second += train_loss.item()


        # print out our model's performance every 50 iterations
        if (i+1) % 50 == 0:
            print(f'Epoch [{epoch+1}/{num_epochs}], Step [{i+1}/{n_total_training_steps}, Train_Loss: {train_loss.item():.4f}]')

    
    scheduler.step(train_loss) # applied every epoch

    # store average loss for this epoch
    train_losses.append(training_running_loss_first / training_halfway)
    train_losses.append(training_running_loss_second / (n_total_training_steps - training_halfway))


print('Finished Training')
print("Total corrupted images skipped:", corrupted)

# path = '../models/model8.pt'
path = '/home/klip/projects/def-brandonh/klip/AI-Art-Detector/models/model8.pt'  # Update this path as needed
def save_model(model, path):
    torch.save(model.state_dict(), path)  # saves model to a file

# save_model(model, path)
# Out:
# === Epoch 1: Current LR: 0.001 ===
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch [1/24], Step [50/250, Train_Loss: 0.5939]
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch [1/24], Step [100/250, Train_Loss: 0.5156]
# Epoch [1/24], Step [150/250, Train_Loss: 0.4519]
# Epoch [1/24], Step [200/250, Train_Loss: 0.5912]
# Epoch [1/24], Step [250/250, Train_Loss: 0.5741]
# === Epoch 2: Current LR: 0.001 ===
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch [2/24], Step [50/250, Train_Loss: 0.4687]
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch [2/24], Step [100/250, Train_Loss: 0.5377]
# Epoch [2/24], Step [150/250, Train_Loss: 0.3585]
# Epoch [2/24], Step [200/250, Train_Loss: 0.4465]
# Epoch [2/24], Step [250/250, Train_Loss: 0.4076]
# === Epoch 3: Current LR: 0.001 ===
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch [3/24], Step [50/250, Train_Loss: 0.4171]
# Epoch [3/24], Step [100/250, Train_Loss: 0.4169]
# Epoch [3/24], Step [150/250, Train_Loss: 0.4663]
# Epoch [3/24], Step [200/250, Train_Loss: 0.2796]
# Epoch [3/24], Step [250/250, Train_Loss: 0.4263]
# === Epoch 4: Current LR: 0.001 ===
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch [4/24], Step [50/250, Train_Loss: 0.3548]
# Epoch [4/24], Step [100/250, Train_Loss: 0.2433]
# Epoch [4/24], Step [150/250, Train_Loss: 0.3797]
# Epoch [4/24], Step [200/250, Train_Loss: 0.4444]
# Epoch [4/24], Step [250/250, Train_Loss: 0.4843]
# === Epoch 5: Current LR: 0.001 ===
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch [5/24], Step [50/250, Train_Loss: 0.4233]
# Epoch [5/24], Step [100/250, Train_Loss: 0.4985]
# Epoch [5/24], Step [150/250, Train_Loss: 0.4324]
# Epoch [5/24], Step [200/250, Train_Loss: 0.4246]
# Epoch [5/24], Step [250/250, Train_Loss: 0.2968]
# === Epoch 6: Current LR: 0.001 ===
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch [6/24], Step [50/250, Train_Loss: 0.4519]
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch [6/24], Step [100/250, Train_Loss: 0.3707]
# Epoch [6/24], Step [150/250, Train_Loss: 0.2465]
# Epoch [6/24], Step [200/250, Train_Loss: 0.4024]
# Epoch [6/24], Step [250/250, Train_Loss: 0.3348]
# === Epoch 7: Current LR: 0.001 ===
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch [7/24], Step [50/250, Train_Loss: 0.3489]
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch [7/24], Step [100/250, Train_Loss: 0.4692]
# Epoch [7/24], Step [150/250, Train_Loss: 0.2591]
# Epoch [7/24], Step [200/250, Train_Loss: 0.4658]
# Epoch [7/24], Step [250/250, Train_Loss: 0.3869]
# === Epoch 8: Current LR: 0.001 ===
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch [8/24], Step [50/250, Train_Loss: 0.3368]
# Epoch [8/24], Step [100/250, Train_Loss: 0.3304]
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch [8/24], Step [150/250, Train_Loss: 0.3019]
# Epoch [8/24], Step [200/250, Train_Loss: 0.4766]
# Epoch [8/24], Step [250/250, Train_Loss: 0.3403]
# === Epoch 9: Current LR: 0.001 ===
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch [9/24], Step [50/250, Train_Loss: 0.2718]
# Epoch [9/24], Step [100/250, Train_Loss: 0.2697]
# Epoch [9/24], Step [150/250, Train_Loss: 0.3321]
# Epoch [9/24], Step [200/250, Train_Loss: 0.3826]
# Epoch [9/24], Step [250/250, Train_Loss: 0.3519]
# === Epoch 10: Current LR: 0.001 ===
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch [10/24], Step [50/250, Train_Loss: 0.3756]
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch [10/24], Step [100/250, Train_Loss: 0.3530]
# Epoch [10/24], Step [150/250, Train_Loss: 0.4927]
# Epoch [10/24], Step [200/250, Train_Loss: 0.3910]
# Epoch [10/24], Step [250/250, Train_Loss: 0.2595]
# === Epoch 11: Current LR: 0.001 ===
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch [11/24], Step [50/250, Train_Loss: 0.3253]
# Epoch [11/24], Step [100/250, Train_Loss: 0.2694]
# Epoch [11/24], Step [150/250, Train_Loss: 0.3524]
# Epoch [11/24], Step [200/250, Train_Loss: 0.3415]
# Epoch [11/24], Step [250/250, Train_Loss: 0.4258]
# === Epoch 12: Current LR: 0.0001 ===
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch [12/24], Step [50/250, Train_Loss: 0.2468]
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch [12/24], Step [100/250, Train_Loss: 0.2474]
# Epoch [12/24], Step [150/250, Train_Loss: 0.3239]
# Epoch [12/24], Step [200/250, Train_Loss: 0.2618]
# Epoch [12/24], Step [250/250, Train_Loss: 0.1745]
# === Epoch 13: Current LR: 0.0001 ===
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch [13/24], Step [50/250, Train_Loss: 0.2451]
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch [13/24], Step [100/250, Train_Loss: 0.2089]
# Epoch [13/24], Step [150/250, Train_Loss: 0.2240]
# Epoch [13/24], Step [200/250, Train_Loss: 0.2899]
# Epoch [13/24], Step [250/250, Train_Loss: 0.4942]
# === Epoch 14: Current LR: 0.0001 ===
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch [14/24], Step [50/250, Train_Loss: 0.1646]
# Epoch [14/24], Step [100/250, Train_Loss: 0.2592]
# Epoch [14/24], Step [150/250, Train_Loss: 0.1839]
# Epoch [14/24], Step [200/250, Train_Loss: 0.4642]
# Epoch [14/24], Step [250/250, Train_Loss: 0.1505]
# === Epoch 15: Current LR: 1e-05 ===
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch [15/24], Step [50/250, Train_Loss: 0.1645]
# Epoch [15/24], Step [100/250, Train_Loss: 0.3023]
# Epoch [15/24], Step [150/250, Train_Loss: 0.1453]
# Epoch [15/24], Step [200/250, Train_Loss: 0.2893]
# Epoch [15/24], Step [250/250, Train_Loss: 0.1757]
# === Epoch 16: Current LR: 1e-05 ===
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch [16/24], Step [50/250, Train_Loss: 0.2575]
# Epoch [16/24], Step [100/250, Train_Loss: 0.1486]
# Epoch [16/24], Step [150/250, Train_Loss: 0.1278]
# Epoch [16/24], Step [200/250, Train_Loss: 0.3052]
# Epoch [16/24], Step [250/250, Train_Loss: 0.2712]
# === Epoch 17: Current LR: 1e-05 ===
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch [17/24], Step [50/250, Train_Loss: 0.1484]
# Epoch [17/24], Step [100/250, Train_Loss: 0.1670]
# Epoch [17/24], Step [150/250, Train_Loss: 0.1946]
# Epoch [17/24], Step [200/250, Train_Loss: 0.2371]
# Epoch [17/24], Step [250/250, Train_Loss: 0.2383]
# === Epoch 18: Current LR: 1e-05 ===
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch [18/24], Step [50/250, Train_Loss: 0.1896]
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch [18/24], Step [100/250, Train_Loss: 0.1337]
# Epoch [18/24], Step [150/250, Train_Loss: 0.1689]
# Epoch [18/24], Step [200/250, Train_Loss: 0.3259]
# Epoch [18/24], Step [250/250, Train_Loss: 0.1999]
# === Epoch 19: Current LR: 1e-05 ===
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch [19/24], Step [50/250, Train_Loss: 0.1452]
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch [19/24], Step [100/250, Train_Loss: 0.3314]
# Epoch [19/24], Step [150/250, Train_Loss: 0.1666]
# Epoch [19/24], Step [200/250, Train_Loss: 0.1642]
# Epoch [19/24], Step [250/250, Train_Loss: 0.1984]
# === Epoch 20: Current LR: 1.0000000000000002e-06 ===
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch [20/24], Step [50/250, Train_Loss: 0.1543]
# Epoch [20/24], Step [100/250, Train_Loss: 0.2085]
# Epoch [20/24], Step [150/250, Train_Loss: 0.3403]
# Epoch [20/24], Step [200/250, Train_Loss: 0.1881]
# Epoch [20/24], Step [250/250, Train_Loss: 0.2854]
# === Epoch 21: Current LR: 1.0000000000000002e-06 ===
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch [21/24], Step [50/250, Train_Loss: 0.2564]
# Epoch [21/24], Step [100/250, Train_Loss: 0.1946]
# Epoch [21/24], Step [150/250, Train_Loss: 0.2369]
# Epoch [21/24], Step [200/250, Train_Loss: 0.1585]
# Epoch [21/24], Step [250/250, Train_Loss: 0.1374]
# === Epoch 22: Current LR: 1.0000000000000002e-06 ===
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch [22/24], Step [50/250, Train_Loss: 0.1799]
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch [22/24], Step [100/250, Train_Loss: 0.1801]
# Epoch [22/24], Step [150/250, Train_Loss: 0.1177]
# Epoch [22/24], Step [200/250, Train_Loss: 0.2285]
# Epoch [22/24], Step [250/250, Train_Loss: 0.3336]
# === Epoch 23: Current LR: 1.0000000000000002e-06 ===
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch [23/24], Step [50/250, Train_Loss: 0.2372]
# Epoch [23/24], Step [100/250, Train_Loss: 0.2071]
# Epoch [23/24], Step [150/250, Train_Loss: 0.1717]
# Epoch [23/24], Step [200/250, Train_Loss: 0.1597]
# Epoch [23/24], Step [250/250, Train_Loss: 0.2598]
# === Epoch 24: Current LR: 1.0000000000000002e-06 ===
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /Users/ssianen/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch [24/24], Step [50/250, Train_Loss: 0.2700]
# Epoch [24/24], Step [100/250, Train_Loss: 0.1260]
# Epoch [24/24], Step [150/250, Train_Loss: 0.2865]
# Epoch [24/24], Step [200/250, Train_Loss: 0.1504]
# Epoch [24/24], Step [250/250, Train_Loss: 0.2021]
# Finished Training
# Total corrupted images skipped: 0

# %%
# Test the model

# Call this function in case you want to use an older model
def load_model(path):
    model = CNN()                               # create empty model
    model.load_state_dict(torch.load(path))     # load a static dict with trained parameters from file to the model
    model.eval()                                # set model to evaluation mode (was previously incorrectly set to train)
    return model

#For network visualization using ONNX file in Netron
#https://docs.pytorch.org/tutorials/beginner/onnx/export_simple_model_to_onnx_tutorial.html

torch_model = load_model('models/model8.pt') # Sophie: Issue with loading pretrained / saved params? RuntimeError: Attempting to deserialize object on a CUDA device but torch.cuda.is_available() is False. 
# torch_model = model 
example_inputs = (torch.randn(1, 3, 64, 64))
onnx_program = torch.onnx.export(torch_model, example_inputs, dynamo=True)
onnx_program.save("AI_Art_Detector_Model8.onnx")
onnx_model = onnx.load("AI_Art_Detector_Model8.onnx")
onnx.checker.check_model(onnx_model)

model.eval()  
with torch.no_grad():
    all_pred_labels = []
    all_labels = []

    TP = 0
    m_samples = 0

    test_loader_iter = iter(test_loader)
    i = 0
    while True:
        try:
            batch = next(test_loader_iter)
            images, labels = batch
            images = images.to(device)
            labels = labels.to(device)
            
            outputs = model(images)
            _, predicted = torch.max(outputs, 1) # max() returns (value, index)
            m_samples += labels.size(0)
                
            i += 1 
        except StopIteration:
            break  
        except OSError:
            corrupted += 1
            i += 1 
            continue

        TP += (predicted == labels).sum().item()

        # convert predicted and actual labels into numpy and add to lists
        all_pred_labels.extend(predicted.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())
        
    # for evaluation we can only print accuracy since we have a perfectly balanced set
    acc = 100.0 * TP / m_samples
    print(f'Accuracy of predicting AI: {acc:.4f} %')
    print("Total corrupted images skipped:", corrupted)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[19], line 13
#       8     return model
#      10 #For network visualization using ONNX file in Netron
#      11 #https://docs.pytorch.org/tutorials/beginner/onnx/export_simple_model_to_onnx_tutorial.html
# ---> 13 torch_model = load_model('models/model8.pt') # Sophie: Issue with loading pretrained / saved params? RuntimeError: Attempting to deserialize object on a CUDA device but torch.cuda.is_available() is False.
#      14 # torch_model = model
#      15 example_inputs = (torch.randn(1, 3, 64, 64))
#
# Cell In[19], line 6, in load_model(path)
#       4 def load_model(path):
#       5     model = CNN()                               # create empty model
# ----> 6     model.load_state_dict(torch.load(path))     # load a static dict with trained parameters from file to the model
#       7     model.eval()                                # set model to evaluation mode (was previously incorrectly set to train)
#       8     return model
#
# File ~/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/torch/serialization.py:1516, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1514 if weights_only:
#    1515     try:
# -> 1516         return _load(
#    1517             opened_zipfile,
#    1518             map_location,
#    1519             _weights_only_unpickler,
#    1520             overall_storage=overall_storage,
#    1521             **pickle_load_args,
#    1522         )
#    1523     except pickle.UnpicklingError as e:
#    1524         raise pickle.UnpicklingError(_get_wo_message(str(e))) from None
#
# File ~/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/torch/serialization.py:2114, in _load(zip_file, map_location, pickle_module, pickle_file, overall_storage, **pickle_load_args)
#    2112 global _serialization_tls
#    2113 _serialization_tls.map_location = map_location
# -> 2114 result = unpickler.load()
#    2115 _serialization_tls.map_location = None
#    2117 torch._utils._validate_loaded_sparse_tensors()
#
# File ~/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/torch/_weights_only_unpickler.py:532, in Unpickler.load(self)
#     524     if (
#     525         type(pid) is tuple
#     526         and len(pid) > 0
#     527         and torch.serialization._maybe_decode_ascii(pid[0]) != "storage"
#     528     ):
#     529         raise UnpicklingError(
#     530             f"Only persistent_load of storage is allowed, but got {pid[0]}"
#     531         )
# --> 532     self.append(self.persistent_load(pid))
#     533 elif key[0] in [BINGET[0], LONG_BINGET[0]]:
#     534     idx = (read(1) if key[0] == BINGET[0] else unpack("<I", read(4)))[0]
#
# File ~/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/torch/serialization.py:2078, in _load.<locals>.persistent_load(saved_id)
#    2076 else:
#    2077     nbytes = numel * torch._utils._element_size(dtype)
# -> 2078     typed_storage = load_tensor(
#    2079         dtype, nbytes, key, _maybe_decode_ascii(location)
#    2080     )
#    2082 return typed_storage
#
# File ~/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/torch/serialization.py:2044, in _load.<locals>.load_tensor(dtype, numel, key, location)
#    2040 # TODO: Once we decide to break serialization FC, we can
#    2041 # stop wrapping with TypedStorage
#    2043 if torch._guards.detect_fake_mode(None) is None:
# -> 2044     wrap_storage = restore_location(storage, location)
#    2045 else:
#    2046     storage._fake_device = location
#
# File ~/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/torch/serialization.py:698, in default_restore_location(storage, location)
#     678 """
#     679 Restores `storage` using a deserializer function registered for the `location`.
#     680
#    (...)    695        all matching ones return `None`.
#     696 """
#     697 for _, _, fn in _package_registry:
# --> 698     result = fn(storage, location)
#     699     if result is not None:
#     700         return result
#
# File ~/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/torch/serialization.py:636, in _deserialize(backend_name, obj, location)
#     634     backend_name = torch._C._get_privateuse1_backend_name()
#     635 if location.startswith(backend_name):
# --> 636     device = _validate_device(location, backend_name)
#     637     return obj.to(device=device)
#
# File ~/Desktop/AI-Art-Detector/CNNEnv/lib/python3.13/site-packages/torch/serialization.py:605, in _validate_device(location, backend_name)
#     603     device_index = device.index if device.index else 0
#     604 if hasattr(device_module, "is_available") and not device_module.is_available():
# --> 605     raise RuntimeError(
#     606         f"Attempting to deserialize object on a {backend_name.upper()} "
#     607         f"device but torch.{backend_name}.is_available() is False. "
#     608         "If you are running on a CPU-only machine, "
#     609         "please use torch.load with map_location=torch.device('cpu') "
#     610         "to map your storages to the CPU."
#     611     )
#     612 if hasattr(device_module, "device_count"):
#     613     device_count = device_module.device_count()
#
# RuntimeError: Attempting to deserialize object on a CUDA device but torch.cuda.is_available() is False. If you are running on a CPU-only machine, please use torch.load with map_location=torch.device('cpu') to map your storages to the CPU.

# %%
# compute accuracy, precision, recall, and f1
accuracy = 100.0 * np.mean(np.array(all_pred_labels) == np.array(all_labels))
precision = 100.0 * precision_score(all_labels, all_pred_labels, zero_division=0)
recall = 100.0 * recall_score(all_labels, all_pred_labels, zero_division=0)
f1 = 100.0 * f1_score(all_labels, all_pred_labels, zero_division=0)

# print metrics first
print(f"Accuracy: {accuracy:.2f}%")
print(f"Precision: {precision:.2f}%")
print(f"Recall: {recall:.2f}%")
print(f"F1 Score: {f1:.2f}%")

# bar chart for test metrics
plt.figure(figsize=(6, 4))
metrics = [accuracy, precision, recall, f1]
labels = ['Accuracy', 'Precision', 'Recall', 'F1 Score']
plt.bar(labels, metrics, color=['blue', 'red', 'green', 'purple'])
plt.title('Test Performance Metrics')
plt.ylabel('Percentage')
plt.ylim(0, 100)
plt.grid(axis='y')
plt.show()


#Plot loss vs epochs
def moving_average(data, window_size=3):
    return [sum(data[max(0, i-window_size+1):i+1]) / (i - max(0, i-window_size+1) + 1) for i in range(len(data))]

window = 5  # try 5 or 7 for smoother curve, play with this!
smooth_train = moving_average(train_losses, window)

plt.figure(figsize=(8, 6))
x_vals = [i / 2 for i in range(1, len(train_losses) + 1)]
plt.plot(x_vals, smooth_train, label='Training Loss (smoothed)', color='blue')
plt.title('Smoothed Training vs Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

#Plot learning rate over epochs
plt.figure(figsize=(8, 6))
smooth_learning = moving_average(learning_rates, window)
x_vals = [i / 2 for i in range(1, len(learning_rates) + 1)]
plt.plot(x_vals, smooth_learning, label='Learning Rate (smoothed)', color='purple')
plt.title('Learning Rate per Epoch')
plt.xlabel('Learning Rate')
plt.ylabel('Epoch')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()


#Plot confusion matrix
cm = confusion_matrix(all_labels, all_pred_labels)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['AI', 'Human'], yticklabels=['AI', 'Human'])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.tight_layout()
plt.show()
# Out:
# Accuracy: 87.22%
# Precision: 87.73%
# Recall: 86.63%
# F1 Score: 87.18%
